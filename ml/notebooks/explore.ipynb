# %%
# %cd ..
# Out:
# /Users/n-zagainov/kolobok/ml

# %%
import pandas as pd

# %%
df = pd.read_json("ocr_results.json")

# %%
df[df["is_tire_size_nonempty"] == 0]
# Out:
#     name  absolutely_correct  max_ratio_brand  max_ratio_model  gt_model  \
# 0     27                 0.5              1.0              0.2  MR-HP172
# 1     18                 1.0              1.0              1.0    P Zero
# 6     19                 1.0              1.0              1.0  MR-HP172
# 30     4                 0.0              0.0              0.0    SnoMax
#
#     gt_brand  is_tire_size_nonempty  \
# 0     Mirage                      0
# 1    Pirelli                      0
# 6     Mirage                      0
# 30  Cordiant                      0
#
#                                            raw_output  execution_time
# 0   {'strings': ['MIRAGE'], 'tire_size': '', 'inde...        8.657585
# 1   {'strings': ['PIRELLI', 'P Zero', 'P', 'Zero',...        9.042065
# 6   {'strings': ['KAMA', 'MR-HP172', 'MR', 'HP172'...        8.101470
# 30  {'strings': [], 'tire_size': '', 'index_result...        8.559176
